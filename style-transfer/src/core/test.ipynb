# %%
from style_transfer import StyleTransfer

# %%
import numpy as np
import scipy.io
import scipy.misc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
IMG_CONTENT = '../img/content.png'
IMG_STYLE = '../img/style.png'
IMG_WIDTH = 360
IMG_HEIGHT = 360
IMG_CHANNEL = 3
content = scipy.misc.imread(IMG_CONTENT)
style = scipy.misc.imread(IMG_STYLE)

# %%
st = StyleTransfer(content, style, IMG_WIDTH, IMG_HEIGHT, IMG_CHANNEL)
# Out:
# /Users/christian/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /Users/christian/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
generated = st.train()

# %%
gen = generated[0].astype(int)
plt.imshow(gen)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(st.img_content[0])

# %%
plt.imshow(st.img_style[0])
